# %% [markdown]
# <H1> My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### James Escano
# Occupation: Head of Quality

# %% [markdown]
# *I am interested in data science because the data tells us a lot of things that could improve our lives.*

# %% [markdown]
# <H3> The code is suppposed to multiply 10 by 10

# %%
10*10
# Out:
# 100

# %% [markdown]
# - one
# - two
# - three
#
#
# <a href="https://en.wikipedia.org/wiki/Philippines">Philippines</a>
#
#
# ![7785_philippinesflag_808379.jpg](attachment:7785_philippinesflag_808379.jpg)
#
# ![images.jpg](attachment:images.jpg)
